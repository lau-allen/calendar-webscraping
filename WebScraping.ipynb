# %%
#Calendar Webscraping & Google API
#Allen Lau

# %%
#importing relevant libraries 
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from IPython.display import HTML
import pendulum as dt
from apiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
#GET request for the CCNY Calendar
req = requests.get('https://www.ccny.cuny.edu/registrar/fall')
#creating BeautifulSoup Object that holds the parsed HTML content of the website
soup = BeautifulSoup(req.text, 'html.parser')
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-83581f4fb59b51cbeb7",applicationID:"254978615"};/*! For license information please see nr-loader-rum-1220.min.js.LICENSE.txt */
# !function(t,e){"object"==typeof exports&&"object"==typeof module?module.exports=e():"function"==typeof define&&define.amd?define([],e):"object"==typeof exports?exports.NRBA=e():t.NRBA=e()}(self,(function(){return function(){var t,e,n={9034:function(t,e,n)

# %%
#finding all tables on the website
all_tables = soup.find_all('table')
print(len(all_tables))
table = all_tables[0]
# Out:
# 1

# %%
#display first indexed table
HTML(table.prettify())
# Out:
# <table align="center" border="3" cellpadding="1" cellspacing="1" style="width:1272px">
#  <thead>
#   <tr>
#    <th class="text-align-left" scope="col" style="width: 305px;">
#     DATES
#    </th>
#    <th class="text-align-left" scope="col" style="width: 327px;">
#     DAYS
#    </th>
#    <th scope="col" style="width: 617px;">
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       August 01
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Sunday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Application for degree for January and February 2022 begins
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      August 18
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Wednesday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      Last day to apply for Study Abroad
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       August 24
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Tuesday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Last day of Registration;
#       <br/>
#       Last day to file ePermit for the Fall 2021;
#       <br/>
#       Last day to drop classes for 100% tuition refund;
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      August 25
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Wednesday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      Start of Fall Term;
#      <br/>
#      Classes begin;
#      <br/>
#      Initial Registration Appeals begin;
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       August 25 - 31
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Wednesday - Tuesday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Change of program period; late fees apply
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      August 26
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Thursday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      Last day for Independent Study
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       August 28
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Saturday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       First day of Saturday Classes
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      August 31
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Tuesday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      Last day to add a class to an existing enrollment;
#      <br/>
#      Last day for 75% tuition refund;
#      <br/>
#      Financial Aid Certification Enrollment Status date;
#      <br/>
#      Last day to apply for Audit option;
#      <br/>
#      Last day to drop without the grade of 'WD';
#      <br/>
#      Initial Registration Appeals end;
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       September 01
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Wednesday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Verification of Enrollment rosters available to faculty;
#       <br/>
#       Course Withdrawal drop period begins (A grade of 'WD' is assigned to students who officially drop a class);
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      September 03 - 08
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Friday - Wednesday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      No classes scheduled
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <strong>
#      September 06
#     </strong>
#    </td>
#    <td style="width:327px">
#     <strong>
#      Monday
#     </strong>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       College Closed;
#       <br/>
#       Last day for 50% tuition refund;
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      September 09
#     </p>
#    </td>
#    <td style="width:327px">
#     Thursday
#    </td>
#    <td style="width:617px">
#     Freshman Convocation
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       September 14
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Tuesday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Last day for 25% tuition refund;
#       <br/>
#       Census date;
#       <br/>
#       Last day to change or declare a major/minor to be effective in Fall 2021;
#       <br/>
#       Last day to drop without the grade of 'W';
#       <br/>
#       Course Withdrawal drop period ends (Last day for 'WD' grades);
#       <br/>
#       Verification of Enrollment Rosters Dues from Faculty;
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      September 15
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Wednesday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      Assignment of 'WN' grades for non-attendance;
#      <br/>
#      Course Withdrawal period begins (A grade of 'W' is assigned to students who officially drop a class) - No Refund;
#      <br/>
#      100% Tuition obligation for course drops;
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       September 15 - 16
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Wednesday - Thursday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       No classes scheduled
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      September 23
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Thursday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      Last day to submit proof of immunization for NYS residents;
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       September 24
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Friday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Assignment of 'WA' grades for immunization non-compliance
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     October 01
#    </td>
#    <td style="width:327px">
#     Friday
#    </td>
#    <td style="width:617px">
#     <p>
#      Advising month begins for Spring and Winter enrollment
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       October 08
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Friday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Deadline for filing application for degree for January and February 2022;
#       <br/>
#       Last day to submit proof of immunization for non-NYS residents;
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      October 11
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Monday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      College Closed
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       November 01
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Monday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       'INC' grades for Spring 2021 and Winter 2021 for Undergraduate students convert to 'FIN';
#       <br/>
#       'INC' grades for Summer 2020 and Fall 2020 for Graduate students convert to 'FIN';
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">

# %%
#finding the table headers using tag 'th'
header = [row for row in table.find_all('th')]
print(header)
# Out:
# [<th class="text-align-left" scope="col" style="width: 305px;">DATES</th>, <th class="text-align-left" scope="col" style="width: 327px;">DAYS</th>, <th scope="col" style="width: 617px;"> </th>]

# %%
#retrieving only the text from the header
col_header = [col.get_text() for col in header]
print(col_header)
# Out:
# ['DATES', 'DAYS', '\xa0']

# %%
#Renaming Column names
col_header[1] = 'DAYS OF THE WEEK'
col_header[2] = 'TEXT'
print(col_header)
# Out:
# ['DATES', 'DAYS OF THE WEEK', 'TEXT']

# %%
#display table column headers 
rawdata = [row for row in table.find_all('tr')]
HTML(rawdata[1].prettify())
# Out:
# <tr>
#  <td style="width:305px">
#   <p>
#    <strong>
#     August 01
#    </strong>
#   </p>
#  </td>
#  <td style="width:327px">
#   <p>
#    <strong>
#     Sunday
#    </strong>
#   </p>
#  </td>
#  <td style="width:617px">
#   <p>
#    <strong>
#     Application for degree for January and February 2022 begins
#    </strong>
#   </p>
#  </td>
# </tr>

# %%
#cleaning up rawdata to remove special characters
#created a list of lists by looping through raw data, finding td tags, and getting the text
data = [[col.get_text(strip = True) for col in row.find_all('td')] for row in rawdata[1:]]
print(data[:5])
# Out:
# [['August 01', 'Sunday', 'Application for degree for January and February 2022 begins'], ['August 18', 'Wednesday', 'Last day to apply for Study Abroad'], ['August 24', 'Tuesday', 'Last day of Registration;Last day to file ePermit for the Fall 2021;Last day to drop classes for 100% tuition refund;'], ['August 25', 'Wednesday', 'Start of Fall Term;Classes begin;Initial Registration Appeals begin;'], ['August 25 - 31', 'Wednesday - Tuesday', 'Change of program period; late fees apply']]

# %%
#create np array
np_value_rows = np.array(data)
np_value_rows[:4]
# Out:
# array([['August 01', 'Sunday',
#         'Application for degree for January and February 2022 begins'],
#        ['August 18', 'Wednesday', 'Last day to apply for Study Abroad'],
#        ['August 24', 'Tuesday',
#         'Last day of Registration;Last day to file ePermit for the Fall 2021;Last day to drop classes for 100% tuition refund;'],
#        ['August 25', 'Wednesday',
#         'Start of Fall Term;Classes begin;Initial Registration Appeals begin;']],
#       dtype='<U274')

# %%
#take data (list of lists) and restructure it using *, zip, and list so that it can be converted into a pandas datatframe
series_list = list(zip(*data))
print(series_list)
# Out:
# [('August 01', 'August 18', 'August 24', 'August 25', 'August 25 - 31', 'August 26', 'August 28', 'August 31', 'September 01', 'September 03 - 08', 'September 06', 'September 09', 'September 14', 'September 15', 'September 15 - 16', 'September 23', 'September 24', 'October 01', 'October 08', 'October 11', 'November 01', 'November 02', 'November 04', 'November 06', 'November 23', 'November 25 - 28', 'December 11', 'December 13', 'December 14', 'December 15 - 21', 'December 21', 'December 24 - 25', 'December 27', 'December 28', 'December 31', 'January 1, 2022'), ('Sunday', 'Wednesday', 'Tuesday', 'Wednesday', 'Wednesday - Tuesday', 'Thursday', 'Saturday', 'Tuesday', 'Wednesday', 'Friday - Wednesday', 'Monday', 'Thursday', 'Tuesday', 'Wednesday', 'Wednesday - Thursday', 'Thursday', 'Friday', 'Friday', 'Friday', 'Monday', 'Monday', 'Tuesday', 'Thursday', 'Saturday', 'Tuesday', 'Thursday - Sunday', 'Saturday', 'Monday', 'Tuesday', 'Wednesday - Tuesday', 'Tuesday', 'Friday - Saturday', 'Monday', 'Tuesday', 'Friday', 'Saturday'), ('Application for degree for January and February 2022 begins', 'Last day to apply for Study Abroad', 'Last day of Registration;Last day to file ePermit for the Fall 2021;Last day to drop classes for 100% tuition refund;', 'Start of Fall Term;Classes begin;Initial Registration Appeals begin;', 'Change of program period; late fees apply', 'Last day for Independent Study', 'First day of Saturday Classes', "Last day to add a class to an existing enrollment;Last day for 75% tuition refund;Financial Aid Certification Enrollment Status date;Last day to apply for Audit option;Last day to drop without the grade of 'WD';Initial Registration Appeals end;", "Verification of Enrollment rosters available to faculty;Course Withdrawal drop period begins (A grade of 'WD' is assigned to students who officially drop a class);", 'No classes scheduled', 'College Closed;Last day for 50% tuition refund;', 'Freshman Convocation', "Last day for 25% tuition refund;Census date;Last day to change or declare a major/minor to be effective in Fall 2021;Last day to drop without the grade of 'W';Course Withdrawal drop period ends (Last day for 'WD' grades);Verification of Enrollment Rosters Dues from Faculty;", "Assignment of 'WN' grades for non-attendance;Course Withdrawal period begins (A grade of 'W' is assigned to students who officially drop a class) - No Refund;100% Tuition obligation for course drops;", 'No classes scheduled', 'Last day to submit proof of immunization for NYS residents;', "Assignment of 'WA' grades for immunization non-compliance", 'Advising month begins for Spring and Winter enrollment', 'Deadline for filing application for degree for January and February 2022;Last day to submit proof of immunization for non-NYS residents;', 'College Closed', "'INC' grades for Spring 2021 and Winter 2021 for Undergraduate students convert to 'FIN';'INC' grades for Summer 2020 and Fall 2020 for Graduate students convert to 'FIN';", 'Registration appointments for Winter and Spring 2022 begin for continuing students.\xa0 Check your CUNYFirst account for your appointment date and time.', 'Last day to file for P/NC option', '60% Date of the term', "'INC' grades for Summer 2021 for Undergraduate students convert to 'FIN'", 'College Closed', 'Last day of Saturday Classes', "Course Withdrawal period ends (Last day to withdraw from a class with the grade of 'W');Last day of Classes;", 'Reading Day', 'Final Examinations', 'End of Term', 'College Closed', 'College Closed', 'Final Grade Submission Deadline for Fall 2021', 'College Closed', 'College Closed;Fall 2021 Degree Conferral Date;')]

# %%
#create pandas DataFrame 
df = pd.DataFrame(dict(zip(col_header,series_list)))
df.head()
# Out:
#             DATES     DAYS OF THE WEEK  \
# 0       August 01               Sunday
# 1       August 18            Wednesday
# 2       August 24              Tuesday
# 3       August 25            Wednesday
# 4  August 25 - 31  Wednesday - Tuesday
#
#                                                 TEXT
# 0  Application for degree for January and Februar...
# 1                 Last day to apply for Study Abroad
# 2  Last day of Registration;Last day to file ePer...
# 3  Start of Fall Term;Classes begin;Initial Regis...
# 4          Change of program period; late fees apply

# %%
#setting index as DATES
df1 = df.set_index('DATES')
df1.head()
# Out:
#                    DAYS OF THE WEEK  \
# DATES
# August 01                    Sunday
# August 18                 Wednesday
# August 24                   Tuesday
# August 25                 Wednesday
# August 25 - 31  Wednesday - Tuesday
#
#                                                              TEXT
# DATES
# August 01       Application for degree for January and Februar...
# August 18                      Last day to apply for Study Abroad
# August 24       Last day of Registration;Last day to file ePer...
# August 25       Start of Fall Term;Classes begin;Initial Regis...
# August 25 - 31          Change of program period; late fees apply

# %%
#using the quick way of creating Dataframe Table
df2 = pd.read_html(str(table))[0]
df2 = df2.rename(columns = {'DAYS':'DAYS OF THE WEEK','Unnamed: 2':'TEXT'})
df2 = df2.set_index('DATES')
df2.head()
# Out:
#                    DAYS OF THE WEEK  \
# DATES
# August 01                    Sunday
# August 18                 Wednesday
# August 24                   Tuesday
# August 25                 Wednesday
# August 25 - 31  Wednesday - Tuesday
#
#                                                              TEXT
# DATES
# August 01       Application for degree for January and Februar...
# August 18                      Last day to apply for Study Abroad
# August 24       Last day of Registration;  Last day to file eP...
# August 25       Start of Fall Term;  Classes begin;  Initial R...
# August 25 - 31          Change of program period; late fees apply

# %%
#using pendulum to format dates correctly for Google API
daterange = []

df3 = pd.read_html(str(table))[0]
df3 = df3.rename(columns = {'DAYS':'DAYS OF THE WEEK','Unnamed: 2':'TEXT'})

for index, date in df3['DATES'].items():
    if ',' in date:
        df3.at[index,'DATES'] = dt.parse(date,tz = 'US/Eastern',strict=False).to_date_string()
    elif '-' not in date:
        df3.at[index,'DATES'] = dt.parse(date + ' 2021',tz = 'US/Eastern',strict=False).to_date_string()
    else:
        date_string = date.split(' -')
        date_string[0] = date_string[0] + ' 2021'
        date_string[1] = date_string[0].split(' ')[0] + date_string[1] + ' 2021'
        daterange = ([dt.parse(date_string[0],strict=False,tz = 'US/Eastern').to_date_string(),dt.parse(date_string[1],strict=False,tz = 'US/Eastern').to_date_string()])
        df3.at[index,"DATES"] = daterange

df3 = df3.set_index("DATES")
df3.head()
# Out:
#                              DAYS OF THE WEEK  \
# DATES
# 2021-08-01                             Sunday
# 2021-08-18                          Wednesday
# 2021-08-24                            Tuesday
# 2021-08-25                          Wednesday
# [2021-08-25, 2021-08-31]  Wednesday - Tuesday
#
#                                                                        TEXT
# DATES
# 2021-08-01                Application for degree for January and Februar...
# 2021-08-18                               Last day to apply for Study Abroad
# 2021-08-24                Last day of Registration;  Last day to file eP...
# 2021-08-25                Start of Fall Term;  Classes begin;  Initial R...
# [2021-08-25, 2021-08-31]          Change of program period; late fees apply

# %% [markdown]
# ###

# %%
#setting up authentication 
scopes = ['https://www.googleapis.com/auth/calendar']
flow = InstalledAppFlow.from_client_secrets_file('credentials2.json',scopes=scopes)

# %%
#credential input
credentials = flow.run_console()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=661183248704-mlf7svvf6p20k97qo794qtgnghqf150p.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=16nvX6ugnK2NQ4PJnNAJMQe7AQooEP&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AWgavdeDRpsjA6yWwGEwTr_2y0cgi8aRjzrA0wxKEfCXqJbYMHWpms2AKbE

# %%
#building service for API  
service = build('calendar','v3',credentials=credentials)

# %%
#building request body and using google api to create events 
for index,descr in df3['TEXT'].items():
    if type(index) == str:
        event = {'start':{'date':index},'end':{'date':index},'summary':descr}
        service.events().insert(calendarId='primary',body=event).execute()
    else:
        event = {'start':{'date':index[0]},'end':{'date':index[1]},'summary':descr}
        service.events().insert(calendarId='primary',body=event).execute()
